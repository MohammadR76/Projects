# %%
from scipy.stats import f, chi2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = f.rvs(30, 10, size = 10000)

# %%
data.std()
# Out:
# np.float64(0.8190850221075764)

# %%
print(data)
# Out:
# [0.72518602 0.94988082 1.69127278 ... 1.13296111 0.7540071  0.74745484]

# %%
plt.hist(data, bins = 100, density=True)
plt.show()

# %%
data2 = chi2.rvs(100, size = 10000)

# %%
plt.hist(data2, bins = 100, density=True)
plt.show()
